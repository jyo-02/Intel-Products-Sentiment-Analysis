# %% [markdown]
# ## Prons & Cons

# %% [markdown]
# #### Read & Clean data

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from tabulate import tabulate

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Load the dataset
df = pd.read_csv('2-dataset_7(senti)_vader.csv')

# Additional stopwords
additional_stopwords = set([
    'also', 'would', 'could', 'like', 'make', 'sure', 'go', 
    'get', 'got', 'recommend', 'highly', 'review', 'want', 'hard'
])

# Combine NLTK and additional stopwords
stop_words = set(stopwords.words('english')).union(additional_stopwords)

def preprocess(text):
    # Remove punctuation, numbers, and convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text).lower()
    # Remove stopwords
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text

# Apply preprocessing to the review column
df['cleaned_review'] = df['Review'].apply(preprocess)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 nltk.download('vader_lexicon')
#      13 # Load the dataset
# ---> 14 df = pd.read_csv('./review_data/dataset_7.csv')
#      16 # Additional stopwords
#      17 additional_stopwords = set([
#      18     'also', 'would', 'could', 'like', 'make', 'sure', 'go',
#      19     'get', 'got', 'recommend', 'highly', 'review', 'want', 'hard'
#      20 ])
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './review_data/dataset_7.csv'

# %% [markdown]
# #### Analyze the data

# %%
sid = SentimentIntensityAnalyzer()

def get_sentiment(bigram):
    return sid.polarity_scores(bigram)['compound']

def analyze_reviews(reviews):
    # Extract bigrams with minimum document frequency of 2
    vectorizer = CountVectorizer(ngram_range=(2, 2), min_df=2)
    X = vectorizer.fit_transform(reviews)
    
    # Sum up the counts of each bigram
    bigram_counts = X.sum(axis=0).A1
    bigram_features = vectorizer.get_feature_names_out()
    
    # Create a DataFrame with the bigrams and their counts
    bigram_df = pd.DataFrame({'bigram': bigram_features, 'count': bigram_counts})
    bigram_df = bigram_df.sort_values(by='count', ascending=False)
    
    # Apply sentiment analysis to the bigrams
    bigram_df['sentiment'] = bigram_df['bigram'].apply(get_sentiment)
    
    # Separate positive and negative bigrams
    positive_bigrams = bigram_df[bigram_df['sentiment'] > 0]
    negative_bigrams = bigram_df[bigram_df['sentiment'] < 0]
    
    # Filter bigrams to keep only meaningful phrases (two words)
    positive_bigrams = positive_bigrams[positive_bigrams['bigram'].apply(lambda x: len(x.split()) == 2)]
    negative_bigrams = negative_bigrams[negative_bigrams['bigram'].apply(lambda x: len(x.split()) == 2)]
    
    # Get the top 5 positive and negative bigrams
    top_5_pros = positive_bigrams.head(5)
    top_5_cons = negative_bigrams.head(5)
    
    return top_5_pros, top_5_cons

# Initialize dictionaries to store the pros and cons for each product
product_pros = {}
product_cons = {}

# Group reviews by product and analyze each group
for product, group in df.groupby('Product'):
    top_5_pros, top_5_cons = analyze_reviews(group['cleaned_review'])
    product_pros[product] = top_5_pros
    product_cons[product] = top_5_cons

# Display the results in a structured format
for product in product_pros:
    print(f"Product: {product}")
    print("Top 5 Positive:")
    print(tabulate(product_pros[product], headers='keys', tablefmt='psql'))
    print("\nTop 5 Negative:")
    if not product_cons[product].empty:
        print(tabulate(product_cons[product], headers='keys', tablefmt='psql'))
    else:
        print("No significant negative bigrams found.")
    print("\n" + "="*50 + "\n")
# Out:
# Product: intel-i3-10100
# Top 5 Pros:
# +-----+--------------+---------+-------------+
# |     | bigram       |   count |   sentiment |
# |-----+--------------+---------+-------------|
# |  59 | good price   |       6 |      0.4404 |
# | 131 | run cool     |       5 |      0.3182 |
# |  36 | easy install |       4 |      0.4404 |
# |  65 | great cpu    |       4 |      0.6249 |
# |  82 | im happy     |       4 |      0.5719 |
# +-----+--------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# |  97 | low power      |       4 |     -0.2732 |
# |  98 | low setting    |       2 |     -0.2732 |
# | 119 | price terrible |       2 |     -0.4767 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i3-12100f
# Top 5 Pros:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 153 | value money    |       7 |      0.34   |
# | 165 | work great     |       6 |      0.6249 |
# |   1 | best budget    |       5 |      0.6369 |
# | 115 | play games     |       5 |      0.34   |
# |  69 | good processor |       5 |      0.4404 |
# +-----+----------------+---------+-------------+
#
# Top 5 Cons:
# +----+--------------+---------+-------------+
# |    | bigram       |   count |   sentiment |
# |----+--------------+---------+-------------|
# |  6 | blade broken |       3 |     -0.4767 |
# | 51 | far cry      |       2 |     -0.4767 |
# | 94 | low power    |       2 |     -0.2732 |
# | 90 | isnt best    |       2 |     -0.5216 |
# +----+--------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i3-13100
# Top 5 Pros:
# +----+----------------+---------+-------------+
# |    | bigram         |   count |   sentiment |
# |----+----------------+---------+-------------|
# | 21 | great price    |       5 |      0.6249 |
# |  1 | best buy       |       4 |      0.6369 |
# | 17 | good processor |       3 |      0.4404 |
# | 39 | turbo boost    |       2 |      0.4019 |
# | 22 | great value    |       2 |      0.7579 |
# +----+----------------+---------+-------------+
#
# Top 5 Cons:
# No significant negative bigrams found.
#
# ==================================================
#
# Product: intel-i5-10400
# Top 5 Pros:
# +-----+--------------+---------+-------------+
# |     | bigram       |   count |   sentiment |
# |-----+--------------+---------+-------------|
# | 182 | value money  |      11 |      0.34   |
# |  48 | easy install |       9 |      0.4404 |
# | 195 | work great   |       9 |      0.6249 |
# |  72 | good price   |       7 |      0.4404 |
# | 154 | run cool     |       6 |      0.3182 |
# +-----+--------------+---------+-------------+
#
# Top 5 Cons:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 103 | low power       |       3 |     -0.2732 |
# | 186 | wa damaged      |       2 |     -0.4404 |
# | 158 | seal broken     |       2 |     -0.4767 |
# | 168 | stopped working |       2 |     -0.2263 |
# |  99 | isnt best       |       2 |     -0.5216 |
# +-----+-----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-10600k
# Top 5 Pros:
# +----+--------------+---------+-------------+
# |    | bigram       |   count |   sentiment |
# |----+--------------+---------+-------------|
# | 78 | work great   |       6 |      0.6249 |
# | 40 | great cpu    |       4 |      0.6249 |
# | 37 | good product |       4 |      0.4404 |
# | 41 | great gaming |       3 |      0.6249 |
# | 16 | easy install |       3 |      0.4404 |
# +----+--------------+---------+-------------+
#
# Top 5 Cons:
# No significant negative bigrams found.
#
# ==================================================
#
# Product: intel-i5-11600k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# |  68 | great price     |       7 |      0.6249 |
# |  62 | good processor  |       5 |      0.4404 |
# |  58 | good cpu        |       5 |      0.4404 |
# |  65 | great cpu       |       4 |      0.6249 |
# | 118 | processor great |       4 |      0.6249 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +----+---------------+---------+-------------+
# |    | bigram        |   count |   sentiment |
# |----+---------------+---------+-------------|
# | 74 | ill update    |       2 |     -0.4215 |
# | 27 | dirty thermal |       2 |     -0.4404 |
# | 47 | gaming rig    |       2 |     -0.128  |
# +----+---------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-12400f
# Top 5 Pros:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# |  83 | good processor |       8 |      0.4404 |
# |  84 | good product   |       7 |      0.4404 |
# | 200 | work great     |       7 |      0.6249 |
# | 183 | value money    |       6 |      0.34   |
# |  94 | great price    |       6 |      0.6249 |
# +-----+----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+------------+---------+-------------+
# |     | bigram     |   count |   sentiment |
# |-----+------------+---------+-------------|
# |  73 | gaming rig |       3 |     -0.128  |
# | 188 | wa broken  |       2 |     -0.4767 |
# |   8 | bad thing  |       2 |     -0.5423 |
# +-----+------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-12600k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 240 | great cpu       |      19 |      0.6249 |
# | 224 | good cpu        |      15 |      0.4404 |
# | 546 | work great      |      15 |      0.6249 |
# | 249 | great processor |      11 |      0.6249 |
# |  30 | best cpu        |       9 |      0.6369 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 472 | stress test     |       4 |     -0.4215 |
# | 210 | gaming rig      |       4 |     -0.128  |
# | 380 | performance low |       2 |     -0.2732 |
# | 554 | wrong cpu       |       2 |     -0.4767 |
# | 524 | wa nervous      |       2 |     -0.2732 |
# +-----+-----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-13400
# Top 5 Pros:
# +----+--------------+---------+-------------+
# |    | bigram       |   count |   sentiment |
# |----+--------------+---------+-------------|
# | 29 | work great   |       4 |      0.6249 |
# |  8 | easy install |       3 |      0.4404 |
# | 28 | well game    |       2 |      0.2732 |
# | 27 | wa easy      |       2 |      0.4404 |
# | 24 | super fast   |       2 |      0.5994 |
# +----+--------------+---------+-------------+
#
# Top 5 Cons:
# No significant negative bigrams found.
#
# ==================================================
#
# Product: intel-i5-13500
# Top 5 Pros:
# +----+-----------------------+---------+-------------+
# |    | bigram                |   count |   sentiment |
# |----+-----------------------+---------+-------------|
# | 19 | good performance      |       4 |      0.4404 |
# | 14 | easy install          |       3 |      0.4404 |
# | 22 | great value           |       3 |      0.7579 |
# | 17 | excellent performance |       3 |      0.5719 |
# | 56 | working great         |       3 |      0.6249 |
# +----+-----------------------+---------+-------------+
#
# Top 5 Cons:
# +----+-----------+---------+-------------+
# |    | bigram    |   count |   sentiment |
# |----+-----------+---------+-------------|
# | 30 | low power |       3 |     -0.2732 |
# +----+-----------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-13600k
# Top 5 Pros:
# +-----+-------------+---------+-------------+
# |     | bigram      |   count |   sentiment |
# |-----+-------------+---------+-------------|
# | 170 | great cpu   |      17 |      0.6249 |
# | 378 | work great  |      13 |      0.6249 |
# |  23 | best value  |      10 |      0.765  |
# | 175 | great price |      10 |      0.6249 |
# |  18 | best bang   |       9 |      0.6369 |
# +-----+-------------+---------+-------------+
#
# Top 5 Cons:
# +-----+--------------+---------+-------------+
# |     | bigram       |   count |   sentiment |
# |-----+--------------+---------+-------------|
# | 290 | problem time |       2 |     -0.4019 |
# | 368 | wa missing   |       2 |     -0.296  |
# |  85 | cpu problem  |       2 |     -0.4019 |
# | 220 | low setting  |       2 |     -0.2732 |
# | 209 | let fool     |       2 |     -0.4404 |
# +-----+--------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i5-14600k
# Top 5 Pros:
# +-----+-------------------+---------+-------------+
# |     | bigram            |   count |   sentiment |
# |-----+-------------------+---------+-------------|
# |  22 | cooling solution  |       5 |      0.3182 |
# | 112 | performance boost |       4 |      0.4019 |
# |  46 | easy install      |       3 |      0.4404 |
# | 133 | super fast        |       3 |      0.5994 |
# | 124 | radiator fan      |       3 |      0.3182 |
# +-----+-------------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 132 | stress test    |       3 |     -0.4215 |
# | 167 | wrong many     |       2 |     -0.4767 |
# | 119 | problem use    |       2 |     -0.4019 |
# |  43 | demanding game |       2 |     -0.2263 |
# |   7 | bad boy        |       2 |     -0.5423 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i7-10700k
# Top 5 Pros:
# +------+-----------------+---------+-------------+
# |      | bigram          |   count |   sentiment |
# |------+-----------------+---------+-------------|
# |  436 | great cpu       |      47 |      0.6249 |
# | 1013 | work great      |      30 |      0.6249 |
# |   46 | best buy        |      28 |      0.6369 |
# |  266 | easy install    |      21 |      0.4404 |
# |  446 | great processor |      20 |      0.6249 |
# +------+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 885 | stress test    |       6 |     -0.4215 |
# | 377 | gaming rig     |       4 |     -0.128  |
# | 886 | stress testing |       3 |     -0.4215 |
# | 386 | geek squad     |       3 |     -0.2023 |
# | 565 | low price      |       3 |     -0.2732 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i7-11700k
# Top 5 Pros:
# +-----+--------------+---------+-------------+
# |     | bigram       |   count |   sentiment |
# |-----+--------------+---------+-------------|
# | 521 | work great   |      33 |      0.6249 |
# | 218 | great cpu    |      26 |      0.6249 |
# | 200 | good cpu     |      20 |      0.4404 |
# | 129 | easy install |      19 |      0.4404 |
# | 524 | work well    |      14 |      0.2732 |
# +-----+--------------+---------+-------------+
#
# Top 5 Cons:
# +-----+---------------------+---------+-------------+
# |     | bigram              |   count |   sentiment |
# |-----+---------------------+---------+-------------|
# | 467 | stress test         |       5 |     -0.4215 |
# | 173 | gaming rig          |       3 |     -0.128  |
# | 399 | processor complaint |       2 |     -0.296  |
# | 393 | problem bought      |       2 |     -0.4019 |
# |  71 | couldnt easier      |       2 |     -0.3252 |
# +-----+---------------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i7-12700k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 314 | great cpu       |      33 |      0.6249 |
# | 715 | work great      |      22 |      0.6249 |
# | 322 | great processor |      18 |      0.6249 |
# |  46 | best buy        |      17 |      0.6369 |
# | 196 | easy install    |      16 |      0.4404 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 623 | stress test    |       4 |     -0.4215 |
# | 520 | problem far    |       3 |     -0.4019 |
# | 467 | pay latest     |       2 |     -0.1027 |
# | 522 | problem havent |       2 |     -0.4019 |
# | 521 | problem gpu    |       2 |     -0.4019 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i7-13700k
# Top 5 Pros:
# +-----+--------------+---------+-------------+
# |     | bigram       |   count |   sentiment |
# |-----+--------------+---------+-------------|
# | 328 | great cpu    |      33 |      0.6249 |
# | 766 | work great   |      18 |      0.6249 |
# | 307 | good cpu     |      14 |      0.4404 |
# | 199 | easy install |      12 |      0.4404 |
# |  44 | best buy     |      12 |      0.6369 |
# +-----+--------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 441 | low temp       |       3 |     -0.2732 |
# | 440 | low power      |       3 |     -0.2732 |
# | 186 | demanding game |       3 |     -0.2263 |
# | 187 | demanding task |       3 |     -0.2263 |
# | 664 | stress test    |       3 |     -0.4215 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i7-14700k
# Top 5 Pros:
# +-----+------------------+---------+-------------+
# |     | bigram           |   count |   sentiment |
# |-----+------------------+---------+-------------|
# | 134 | great cpu        |      10 |      0.6249 |
# |  84 | easy install     |       8 |      0.4404 |
# |  16 | best buy         |       8 |      0.6369 |
# |  43 | cooling solution |       7 |      0.3182 |
# | 128 | good cooling     |       6 |      0.4404 |
# +-----+------------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 278 | stress test    |       4 |     -0.4215 |
# |  77 | demanding game |       3 |     -0.2263 |
# | 243 | problem use    |       2 |     -0.4019 |
# | 312 | wa doa         |       2 |     -0.5106 |
# | 318 | wa problem     |       2 |     -0.4019 |
# +-----+----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i9-10900k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# |  37 | best buy        |      24 |      0.6369 |
# | 244 | great cpu       |      21 |      0.6249 |
# | 253 | great processor |      19 |      0.6249 |
# | 151 | easy install    |      13 |      0.4404 |
# | 532 | work great      |      13 |      0.6249 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 476 | stress test     |       5 |     -0.4215 |
# |  30 | bad boy         |       3 |     -0.5423 |
# | 133 | crazy fast      |       3 |     -0.34   |
# | 101 | couldnt happier |       3 |     -0.4168 |
# | 540 | wrong one       |       2 |     -0.4767 |
# +-----+-----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i9-11900k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 134 | great cpu       |      19 |      0.6249 |
# | 124 | good cpu        |      10 |      0.4404 |
# | 294 | work great      |       9 |      0.6249 |
# | 139 | great product   |       7 |      0.6249 |
# | 138 | great processor |       7 |      0.6249 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+---------------+---------+-------------+
# |     | bigram        |   count |   sentiment |
# |-----+---------------+---------+-------------|
# |  14 | bad thing     |       3 |     -0.5423 |
# | 285 | waste money   |       2 |     -0.4215 |
# | 283 | wa terrible   |       2 |     -0.4767 |
# |  56 | couldnt happy |       2 |     -0.4585 |
# |  13 | bad cpu       |       2 |     -0.5423 |
# +-----+---------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i9-12900k
# Top 5 Pros:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 292 | great processor |      20 |      0.6249 |
# | 286 | great cpu       |      19 |      0.6249 |
# | 657 | work great      |      18 |      0.6249 |
# | 180 | easy install    |      17 |      0.4404 |
# |  43 | best buy        |      15 |      0.6369 |
# +-----+-----------------+---------+-------------+
#
# Top 5 Cons:
# +-----+-------------+---------+-------------+
# |     | bigram      |   count |   sentiment |
# |-----+-------------+---------+-------------|
# | 420 | new rig     |       2 |     -0.128  |
# | 620 | usually low |       2 |     -0.2732 |
# | 127 | cpu limited |       2 |     -0.2263 |
# |  36 | bad cpu     |       2 |     -0.5423 |
# | 385 | lower temp  |       2 |     -0.296  |
# +-----+-------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i9-13900k
# Top 5 Pros:
# +-----+------------+---------+-------------+
# |     | bigram     |   count |   sentiment |
# |-----+------------+---------+-------------|
# |  65 | best buy   |      25 |      0.6369 |
# |  68 | best cpu   |      24 |      0.6369 |
# | 993 | work great |      20 |      0.6249 |
# | 857 | super fast |      18 |      0.5994 |
# | 400 | great cpu  |      15 |      0.6249 |
# +-----+------------+---------+-------------+
#
# Top 5 Cons:
# +-----+-----------------+---------+-------------+
# |     | bigram          |   count |   sentiment |
# |-----+-----------------+---------+-------------|
# | 222 | demanding task  |       5 |     -0.2263 |
# | 162 | couldnt happier |       5 |     -0.4168 |
# | 853 | stress test     |       5 |     -0.4215 |
# | 713 | problem cpu     |       4 |     -0.4019 |
# | 365 | geek squad      |       4 |     -0.2023 |
# +-----+-----------------+---------+-------------+
#
# ==================================================
#
# Product: intel-i9-14900k
# Top 5 Pros:
# +-----+--------------------+---------+-------------+
# |     | bigram             |   count |   sentiment |
# |-----+--------------------+---------+-------------|
# | 176 | great cpu          |       9 |      0.6249 |
# | 171 | good cpu           |       8 |      0.4404 |
# |  63 | cooling solution   |       8 |      0.3182 |
# | 227 | keep cool          |       7 |      0.3182 |
# | 319 | powerful processor |       6 |      0.4215 |
# +-----+--------------------+---------+-------------+
#
# Top 5 Cons:
# +-----+----------------+---------+-------------+
# |     | bigram         |   count |   sentiment |
# |-----+----------------+---------+-------------|
# | 373 | stress test    |       3 |     -0.4215 |
# | 203 | ill wait       |       3 |     -0.4215 |
# | 321 | problem use    |       2 |     -0.4019 |
# | 439 | wrong many     |       2 |     -0.4767 |
# | 105 | demanding game |       2 |     -0.2263 |
# +-----+----------------+---------+-------------+
#
# ==================================================
